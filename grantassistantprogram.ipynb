# %% [markdown]
# <a href="https://colab.research.google.com/github/ReidelVichot/GrantAssistProgram/blob/main/grantassistantprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests
from zipfile import ZipFile

# %%
#Get the zip from the website
req = requests.get('https://files.usaspending.gov/generated_downloads/PrimeAwardSummariesAndSubawards_2022-10-24_H17M00S24553263.zip', allow_redirects=True)

#Open the zip as a file
with open("PrimeAwardSummariesAndSubawards_2022-10-24_H17M00S24553263.zip", "wb") as file:
    file.write(req.content)

#Extract the zip
with ZipFile('PrimeAwardSummariesAndSubawards_2022-10-24_H17M00S24553263.zip', 'r') as zipObj:
   zipObj.extractall()

# %%
#Get the document as a csv
df = pd.read_csv("Assistance_PrimeAwardSummaries_2022-10-24_H17M00S24_1.csv")

# %%
df
# Out:
#        assistance_award_unique_key    award_id_fain  award_id_uri  \
# 0     ASST_NON_E14-MC-10-0001_8620   E14-MC-10-0001           NaN
# 1          ASST_NON_DEH20F001_8620        DEH20F001           NaN
# 2         ASST_NON_DEH19-F001_8620       DEH19-F001           NaN
# 3       ASST_NON_2009CKWX0663_1550     2009CKWX0663           NaN
# 4       ASST_NON_2020DJBX0223_1550     2020DJBX0223           NaN
# ..                             ...              ...           ...
# 100  ASST_NON_B-18-MC-10-0001_8620  B-18-MC-10-0001           NaN
# 101  ASST_NON_E-19-MC-10-0001_8620  E-19-MC-10-0001           NaN
# 102     ASST_NON_2011DJBX3200_1550     2011DJBX3200           NaN
# 103       ASST_NON_G17PC0009A_1127       G17PC0009A           NaN
# 104         ASST_NON_97374001_6800         97374001           NaN
#
#             sai_number                      disaster_emergency_fund_codes  \
# 0                  NaN                                                NaN
# ...
